# %% [markdown]
# ## Backpropagation in CNNs

# %% [markdown]
# Basic logical Flow of CNNs

# %% [markdown]
# ![WhatsApp Image 2026-04-10 at 2.16.27 PM.jpeg](<attachment:WhatsApp Image 2026-04-10 at 2.16.27 PM.jpeg>)

# %% [markdown]
# For simplicity consider this logic flow (here we only have one dense layer)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now, A2 is output ($\hat{y}$), and L is loss, we have to minimize it.
# And we have 4 trainable parameters here, $W_1, b_1, W_2, b_2$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# But how do we calculate derivatives of convolution, pooling, flatten? We'll see

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
